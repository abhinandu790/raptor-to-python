# %% [markdown]
# 1. Find the sum of two numbers

# %%
#integer
num1=int(input("Enter the fisrt number :"))
num2=int(input("Enter the second number :"))
sum=num1+num2
print("Sum is",sum)

# %% [markdown]
# 2. Calculate the area and perimeter of triangle

# %%
#float
a=float(input("Enter the value of a:"))
b=float(input("Enter the value of b:"))
c=float(input("Enter the value of c:"))
perimeter=a+b+c
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**(1/2)
print("Perimeter is :",perimeter)
print("Area is :",area)

# %% [markdown]
# 3. Calculate the area of circle

# %%
#float
r=float(input("Enter the radius:"))
area=3.14*(r**2)
print("Area is :",area)

# %% [markdown]
# 4. Calculate the sum and average of 3 numbers

# %%
#integer
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
num3=int(input("Enter the third number:"))
sum=num1+num2+num3
avg=sum/3
print("Sum is ",sum)
print("Average is ",avg)

# %% [markdown]
# 5. Calculate the number of years,months, and days from a given number of days

# %% [markdown]
# 6. Convert seconds to hour, minute and seconds

# %% [markdown]
# 7. Calculate sum, difference, product and quotient of two numbers

# %%
#float
#integer
num1=float(input("Enter the first number:"))
num2=float(input("Enter the second number:"))
sum =num1+num2
difference=num1-num2
product=num1*num2
quotient=num1//num2
print("Sum is :",sum)
print("Product is :",product)
print("Difference is :",difference)
print("Product is :",product)
print("Quotient is :",quotient)

# %% [markdown]
# 8. Find roots of quadratic equations

# %%
#float
import math
a=float(input("Enter the value of a :"))
b=float(input("Enter the value of b :"))
c=float(input("Enter the value of c :"))
x1 = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
x2 = (-b - math.sqrt(b**2 - 4*a*c)) / (2*a)
print("Roots are :",x1,x2)

# %% [markdown]
# 9. Calculate the percentage of 5 subjects

# %%
s1=int(input("Enter mark of subject 1 :"))
s2=int(input("Enter mark of subject 2 :"))
s3=int(input("Enter mark of subject 3 :"))
s4=int(input("Enter mark of subject 4 :"))
s5=int(input("Enter mark of subject 5 :"))
max=int(input("Maximum mark of 5 subject is :"))
tot=s1+s2+s3+s4+s5
avg=tot/5
per=(tot/max)*100
print("Percentage of 5 subjects are : ",per," %")

# %% [markdown]
# 10. Convert Celsius to Fahrenheit

# %%
#float
c=float(input("Enter the celsuis :"))
f=9/5*c+32
print("Fahrenheit is :",f)
